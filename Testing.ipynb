# %% [markdown]
# # TEK5030: Velocity Tracking - Testing

# %%
from source_code import video_feed
import numpy as np
import cv2 as cv2
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
imNight = plt.imread("nightKing.jpg")
plt.imshow(imNight)

# %%
imGray = cv2.cvtColor(imNight, cv2.COLOR_BGR2HSV)
print(imGrey.shape)
plt.imshow(imGrey, cmap='gray')
# Out:
# (720, 1280)

# %%
imLog = video_feed.extract_blob_features(imNight)
print(imLog.max())
print(imLog.min())
#imLog *= (255/imLog.max())
plt.imshow(imLog)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-196-81b496398c3d> in <module>
# ----> 1 imLog = video_feed.extract_blob_features(imNight)
#       2 print(imLog.max())
#       3 print(imLog.min())
#       4 #imLog *= (255/imLog.max())
#       5 plt.imshow(imLog)
#
# TypeError: extract_blob_features() missing 2 required positional arguments: 'ddepth' and 'ksize'

# %%
imDiff = imLog - imNight
plt.imshow(imDiff)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
lower_blue = np.array([0,50,0])
upper_blue = np.array([0,255,0])
mask = cv2.inRange(imGray, lower_blue, upper_blue)
plt.imshow(mask)

res = cv2.bitwise_and(imGray,imGray, mask=mask)
plt.imshow(res)



#thresh, imOtsu = cv2.threshold(imGray, cv2.THRESH_OTSU, 50, cv2.THRESH_TRUNC)
#print(thresh)
#plt.imshow(imOtsu, cmap='gray')
# Out:
# (720, 1280)

# %%
imLapGau = video_feed.extract_blob_features(image=imNight,ddepth=3,ksize=5,bsize=3)
for i in range(3):
    plt.subplot(3,1,i+1)
    plt.imshow(imLapGau[:,:,i], cmap='gray')
# Out:
# (720, 1280, 3)
# (720, 1280, 3)
